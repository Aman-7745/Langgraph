# %%
¸
# Out:
# /Users/aman/Work/Generative AI/Langraph/venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
load_dotenv
model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    title : str
    outline : str
    content : str

# %%
def create_outline(state:BlogState)-> BlogState:
    # fetch title

    title = state['title']

    prompt = f'Generate  a deteiled outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state : BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f'write a detailed blog on the title ={title} using the following outline \n{outline}'

    content = model.invoke(prompt)

    state['content'] = content

    return state

# %%
graph =  StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog',create_blog)

# edges
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
iniital_state = {'title':'Rise of AI in India'}

final_state =  workflow.invoke(iniital_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "I. Introduction\n    A. Brief overview of Artificial Intelligence (AI) and its significance in the modern world\n    B. Introduction to the topic of the rise of AI in India\n\nII. Current state of AI in India\n    A. Overview of the current applications of AI in various industries in India\n    B. Key players in the AI industry in India\n    C. Challenges and opportunities for AI development in India\n\nIII. Government initiatives and policies to promote AI in India\n    A. Overview of government schemes and initiatives to promote AI in India\n    B. Analysis of the impact of government policies on the growth of AI in India\n    C. Comparison of India's AI policies with other countries\n\nIV. Rise of AI startups in India\n    A. Overview of the AI startup ecosystem in India\n    B. Success stories of AI startups in India\n    C. Challenges faced by AI startups in India\n\nV. Impact of AI on the Indian economy and society\n    A. Economic benefits of AI in India\n    B. Social and ethical implications of AI adoption in India\n    C. Job displacement and upskilling in the age of AI\n\nVI. Future prospects of AI in India\n    A. Potential areas for growth and development of AI in India\n    B. Predictions for the future of AI in India\n    C. Recommendations for policymakers, businesses, and individuals to harness the potential of AI in India\n\nVII. Conclusion\n    A. Recap of key points discussed in the blog\n    B. Final thoughts on the rise of AI in India and its implications for the future", 'content': AIMessage(content="\n\nI. Introduction\n\nArtificial Intelligence (AI) is a rapidly evolving technology that has the potential to revolutionize industries and change the way we live and work. It involves the development of computer systems that can perform tasks that normally require human intelligence, such as speech recognition, decision-making, and problem-solving. The rise of AI in India is a significant trend that is transforming various sectors and driving innovation and growth in the country.\n\nII. Current state of AI in India\n\nIndia has seen a surge in the adoption of AI across various industries such as healthcare, finance, education, agriculture, and manufacturing. Companies like Infosys, Wipro, Tata Consultancy Services (TCS), and startups like Niki.ai, Niramai, and Grey Orange are leading the way in AI development in India. However, there are still challenges such as data privacy concerns, lack of skilled talent, and regulatory hurdles that need to be addressed to fully realize the potential of AI in India.\n\nIII. Government initiatives and policies to promote AI in India\n\nThe Indian government has taken steps to promote AI development in the country through initiatives like the National AI Strategy, Digital India, and the National AI Portal. These policies aim to boost AI research, innovation, and adoption in various sectors. However, there is still a need for more robust regulatory frameworks and investments in AI research and development to compete with global players like the US and China.\n\nIV. Rise of AI startups in India\n\nThe AI startup ecosystem in India is thriving with a growing number of companies focusing on AI technologies like machine learning, natural language processing, and computer vision. Success stories like Freshworks, InMobi, and Zoho are inspiring other startups to venture into the AI space. Challenges faced by AI startups in India include funding constraints, talent acquisition, and navigating complex regulatory environments.\n\nV. Impact of AI on the Indian economy and society\n\nAI is expected to contribute significantly to the Indian economy by boosting productivity, creating new job opportunities, and driving innovation. However, there are concerns about the social and ethical implications of AI adoption, such as bias in algorithms, data privacy, and job displacement. Upskilling the workforce and implementing ethical AI practices are  ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief overview of Artificial Intelligence (AI) and its significance in the modern world
#     B. Introduction to the topic of the rise of AI in India
#
# II. Current state of AI in India
#     A. Overview of the current applications of AI in various industries in India
#     B. Key players in the AI industry in India
#     C. Challenges and opportunities for AI development in India
#
# III. Government initiatives and policies to promote AI in India
#     A. Overview of government schemes and initiatives to promote AI in India
#     B. Analysis of the impact of government policies on the growth of AI in India
#     C. Comparison of India's AI policies with other countries
#
# IV. Rise of AI startups in India
#     A. Overview of the AI startup ecosystem in India
#     B. Success stories of AI startups in India
#     C. Challenges faced by AI startups in India
#
# V. Impact of AI on the Indian economy and society
#     A. Economic benefits of AI in India
#     B. Social and ethical implications of AI adoption in India
#     C. Job displacement and upskilling in the age of AI
#
# VI. Future prospects of AI in India
#     A. Potential areas for growth and development of AI in India
#     B. Predictions for the future of AI in India
#     C. Recommendations for policymakers, businesses, and individuals to harness the potential of AI in India
#
# VII. Conclusion
#     A. Recap of key points discussed in the blog
#     B. Final thoughts on the rise of AI in India and its implications for the future

# %%
print(final_state['content'])
# Out:
# content="\n\nI. Introduction\n\nArtificial Intelligence (AI) is a rapidly evolving technology that has the potential to revolutionize industries and change the way we live and work. It involves the development of computer systems that can perform tasks that normally require human intelligence, such as speech recognition, decision-making, and problem-solving. The rise of AI in India is a significant trend that is transforming various sectors and driving innovation and growth in the country.\n\nII. Current state of AI in India\n\nIndia has seen a surge in the adoption of AI across various industries such as healthcare, finance, education, agriculture, and manufacturing. Companies like Infosys, Wipro, Tata Consultancy Services (TCS), and startups like Niki.ai, Niramai, and Grey Orange are leading the way in AI development in India. However, there are still challenges such as data privacy concerns, lack of skilled talent, and regulatory hurdles that need to be addressed to fully realize the potential of AI in India.\n\nIII. Government initiatives and policies to promote AI in India\n\nThe Indian government has taken steps to promote AI development in the country through initiatives like the National AI Strategy, Digital India, and the National AI Portal. These policies aim to boost AI research, innovation, and adoption in various sectors. However, there is still a need for more robust regulatory frameworks and investments in AI research and development to compete with global players like the US and China.\n\nIV. Rise of AI startups in India\n\nThe AI startup ecosystem in India is thriving with a growing number of companies focusing on AI technologies like machine learning, natural language processing, and computer vision. Success stories like Freshworks, InMobi, and Zoho are inspiring other startups to venture into the AI space. Challenges faced by AI startups in India include funding constraints, talent acquisition, and navigating complex regulatory environments.\n\nV. Impact of AI on the Indian economy and society\n\nAI is expected to contribute significantly to the Indian economy by boosting productivity, creating new job opportunities, and driving innovation. However, there are concerns about the social and ethical implications of AI adoption, such as bias in algorithms, data privacy, and job displacement. Upskilling the workforce and implementing ethical AI practices are essential to ensure a fair and inclusive AI-driven future for India.\n\nVI. Future prospects of AI in India\n\nThe future of AI in India looks promising with potential growth opportunities in sectors like healthcare, agriculture, education, and e-commerce. Predictions for the future include advancements in AI technology, increased investments in AI research and development, and greater collaboration between industry, academia, and the government. Recommendations for policymakers, businesses, and individuals include investing in AI education and training, fostering collaboration and partnerships, and promoting ethical AI practices.\n\nVII. Conclusion\n\nIn conclusion, the rise of AI in India represents a transformative shift in the country's technological landscape with immense potential for growth and innovation. It is crucial for stakeholders to address challenges, seize opportunities, and work together to harness the power of AI for the benefit of society and the economy. The future of AI in India is bright and exciting, and with the right policies and strategies in place, India can position itself as a global leader in AI development." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 641, 'prompt_tokens': 355, 'total_tokens': 996, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprin ...
